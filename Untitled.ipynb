# %%
# Загрузим библиотеки и датасет.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 45) # показывать больше строк
pd.set_option('display.max_columns', 30) # показывать больше колонок

students=pd.read_csv('stud_math.xls')

# %%
display(students.head(15))
students.info()
# Посмотрим, с чем мы имеем дело.
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1      GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3      GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services     other
# 6      GP   M   16     NaN     LE3       T   2.0   2.0     other     other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other   teacher
# 8      GP   M   15       U     LE3       A   3.0   2.0  services     other
# 9      GP   M   15       U     NaN     NaN   3.0   4.0     other     other
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher    health
# ...

# %%
# количество пустых значений
students.isnull().sum()
# Out:
# school                  0
# sex                     0
# age                     0
# address                17
# famsize                27
# Pstatus                45
# Medu                    3
# Fedu                   24
# Mjob                   19
# Fjob                   36
# reason                 17
# guardian               31
# traveltime             28
# studytime               7
# failures               22
# schoolsup               9
# famsup                 39
# paid                   40
# activities             14
# nursery                16
# studytime, granular     7
# higher                 20
# internet               34
# romantic               31
# famrel                 27
# freetime               11
# goout                   8
# health                 15
# absences               12
# score                   6
# dtype: int64

# %%
students.duplicated().sum() # количество дубликатов. (На всякий случай)
# Out:
# 0

# %%
# Переменуем некоторые колонки для удобства.
students.rename(columns={'Pstatus': 'parent_status', 'Medu': 'mother_edu','Fedu': 'father_edu',
                         'Mjob': 'mother_job', 'Fjob': 'father_job'}, inplace=True)
students
# Out:
#     school sex  age address famsize parent_status  mother_edu  father_edu  \
# 0       GP   F   18       U     NaN             A         4.0         4.0
# 1       GP   F   17       U     GT3           NaN         1.0         1.0
# 2       GP   F   15       U     LE3             T         1.0         1.0
# 3       GP   F   15       U     GT3             T         4.0         2.0
# 4       GP   F   16       U     GT3             T         3.0         3.0
# ..     ...  ..  ...     ...     ...           ...         ...         ...
# 390     MS   M   20       U     LE3             A         2.0         2.0
# 391     MS   M   17       U     LE3             T         3.0         1.0
# 392     MS   M   21       R     GT3             T         1.0         1.0
# 393     MS   M   18       R     LE3             T         3.0         2.0
# 394     MS   M   19       U     LE3             T         1.0         1.0
#
#     mother_job father_job  reason guardian  traveltime  studytime  failures  \
# ...

# %%
# Посмотрим, в общем, на числовые колонки.
summary=students.describe()
summary = summary.transpose()
summary
## Мы видим на первый взгляд три выброса: father_edu (40), famrel(-1), absences(385).
## Также видим подозрительную колонку с отрицательными значениями - studytime, granular.
## В дальнейшем увидим действительно ли это так.
# Out:
#                      count       mean        std   min   25%   50%   75%  \
# age                  395.0  16.696203   1.276043  15.0  16.0  17.0  18.0
# mother_edu           392.0   2.750000   1.098127   0.0   2.0   3.0   4.0
# father_edu           371.0   2.614555   2.228732   0.0   2.0   2.0   3.0
# traveltime           367.0   1.438692   0.694181   1.0   1.0   1.0   2.0
# studytime            388.0   2.038660   0.842078   1.0   1.0   2.0   2.0
# failures             373.0   0.337802   0.743135   0.0   0.0   0.0   0.0
# studytime, granular  388.0  -6.115979   2.526235 -12.0  -6.0  -6.0  -3.0
# famrel               368.0   3.937500   0.927277  -1.0   4.0   4.0   5.0
# freetime             384.0   3.231771   0.993940   1.0   3.0   3.0   4.0
# goout                387.0   3.105943   1.115896   1.0   2.0   3.0   4.0
# health               380.0   3.531579   1.396019   1.0   3.0   4.0   5.0
# absences             383.0   7.279373  23.465197   0.0   0.0   4.0   8.0
# ...

# %%
# Т.к. всего скорее колонка studytime, granular ошибочна (её нет в описании проекта, непереводимое логически название,
# у неё отрицательные значения, она явно выбивается из датасета), то мы её удаляем.
students.drop(['studytime, granular'], inplace = True, axis = 1)

# %%
students.describe(include= 'object')
# В общем, посмотрим на строковые колонки.
# Здесь всё нормально, не видно что-либо подозрительного.
# Out:
#        school  sex address famsize parent_status mother_job father_job  \
# count     395  395     378     368           350        376        359
# unique      2    2       2       2             2          5          5
# top        GP    F       U     GT3             T      other      other
# freq      349  208     295     261           314        133        197
#
#         reason guardian schoolsup famsup paid activities nursery higher  \
# count      378      364       386    356  355        381     379    375
# unique       4        3         2      2    2          2       2      2
# top     course   mother        no    yes   no        yes     yes    yes
# freq       137      250       335    219  200        195     300    356
#
#        internet romantic
# count       361      364
# unique        2        2
# top         yes       no
# freq        305      240

# %%
# Дальше переходим к более детальному разбору.

# %%
print("Уникальных значений:", students.school.nunique())
print("Пустых значений:", students.school.isnull().sum())
display(pd.DataFrame(students.school.value_counts()))
students.school.hist()
# Видим, что большинство учится в GP-школе.
# Out:
# Уникальных значений: 2
# Пустых значений: 0
#     school
# GP     349
# MS      46

# %%
print("Уникальных значений:", students.sex.nunique())
print("Пустых значений:", students.sex.isnull().sum())
display(pd.DataFrame(students.sex.value_counts()))
students.sex.hist()
# Мальчиков и девочек примерно одинаковое количество.
# Out:
# Уникальных значений: 2
# Пустых значений: 0
#    sex
# F  208
# M  187

# %%
print("Уникальных значений:", students.age.nunique())
print("Пустых значений:", students.age.isnull().sum())
display(pd.DataFrame(students.age.value_counts()))
students.age.hist()
# В проекте написан возраст учеников от 15 до 22. Все значения входят в эти рамки. Возраст 20-22 выбросом считать не буду.
# Out:
# Уникальных значений: 8
# Пустых значений: 0
#     age
# 16  104
# 17   98
# 18   82
# 15   82
# 19   24
# 20    3
# 22    1
# 21    1

# %%
print("Уникальных значений:", students.address.nunique())
print("Пустых значений:", students.address.isnull().sum())
display(pd.DataFrame(students.address.value_counts()))
students.address.hist()
# Большинство учеников, которые живут в городе.
# Out:
# Уникальных значений: 2
# Пустых значений: 17
#    address
# U      295
# R       83

# %%
ad_s = students[students.address.isnull()]
ad_s.traveltime.value_counts()
# Смотрим какие значения traveltime в пустых строках address.
# Out:
# 1.0    8
# 2.0    5
# 3.0    1
# Name: traveltime, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['traveltime'] <= 2.0) & (students.address.isnull()) , 'address'] = 'U'
students.loc[(students['traveltime'] > 2.0) & (students.address.isnull()) , 'address'] = 'R'
display(pd.DataFrame(students.address.value_counts()))
# Out:
#    address
# U      308
# R       84

# %%
print("Пустых значений:", students.address.isnull().sum())
# Осталось ещё три пустых значения.
# Out:
# Пустых значений: 3

# %%
students.address = students.address.astype(str).apply(lambda x: 'U' if x.strip() == 'nan' else x)
# Распределим их в городских, как по более вероятному значению.

# %%
print("Уникальных значений:", students.famsize.nunique())
print("Пустых значений:", students.famsize.isnull().sum())
display(pd.DataFrame(students.famsize.value_counts()))
students.famsize.hist()
# В большинстве семей больше трёх человек.
# Out:
# Уникальных значений: 2
# Пустых значений: 27
#      famsize
# GT3      261
# LE3      107

# %%
f_s = students[students.famsize.isnull()]
f_s.parent_status.value_counts()
# Смотрим какие значения parent_status в пустых строках famsize.
# Out:
# T    20
# A     3
# Name: parent_status, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['parent_status'] == 'T') & (students.famsize.isnull()), 'famsize'] = 'GT3'
students.loc[(students['parent_status'] == 'A') & (students.famsize.isnull()), 'famsize'] = 'LE3'
display(pd.DataFrame(students.famsize.value_counts()))
# Out:
#      famsize
# GT3      281
# LE3      110

# %%
print("Пустых значений:", students.famsize.isnull().sum())
# Осталось четыре пустых значения, дополним их чуть позже.
# Out:
# Пустых значений: 4

# %%
print("Уникальных значений:", students.parent_status.nunique())
print("Пустых значений:", students.parent_status.isnull().sum())
display(pd.DataFrame(students.parent_status.value_counts()))
students.parent_status.hist()
# Большинство семей, где родители живут вместе.
# Out:
# Уникальных значений: 2
# Пустых значений: 45
#    parent_status
# T            314
# A             36

# %%
p_s = students[students.parent_status.isnull()]
p_s.famrel.value_counts()
# Смотрим какие значения famrel в пустых строках parent_status.
# Out:
#  4.0    20
#  5.0    13
#  3.0     9
#  1.0     2
# -1.0     1
# Name: famrel, dtype: int64

# %%
students.loc[students['famrel'] == -1.0, 'famrel'] = 1.0
# Всего скорее, отрицательное значение человеческая ошибка, исправим на 1.0.

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['famrel'] > 2) & (students.parent_status.isnull()), 'parent_status'] = 'T'
students.loc[(students['famrel'] <= 2) & (students.parent_status.isnull()), 'parent_status'] = 'A'
display(pd.DataFrame(students.parent_status.value_counts()))
# Out:
#    parent_status
# T            356
# A             39

# %%
print("Пустых значений:", students.parent_status.isnull().sum())
# Out:
# Пустых значений: 0

# %%
# Настало время дозаполнить оставшиеся четыре значения famsize, о которых говорилось чуть выше.
students.loc[(students['parent_status'] == 'T') & (students.famsize.isnull()), 'famsize'] = 'GT3'
students.loc[(students['parent_status'] == 'A') & (students.famsize.isnull()), 'famsize'] = 'LE3'
display(pd.DataFrame(students.famsize.value_counts()))
print("Пустых значений:", students.famsize.isnull().sum())
# Out:
#      famsize
# GT3      285
# LE3      110
# Пустых значений: 0

# %%
print("Уникальных значений:", students.mother_edu.nunique())
print("Пустых значений:", students.mother_edu.isnull().sum())
display(pd.DataFrame(students.mother_edu.value_counts()))
students.mother_edu.hist()
# Много матерей с высшим образованием.
# Out:
# Уникальных значений: 5
# Пустых значений: 3
#      mother_edu
# 4.0         131
# 2.0         102
# 3.0          97
# 1.0          59
# 0.0           3

# %%
students.mother_edu.median()
# Заполним пустые значения медианой.
# Out:
# 3.0

# %%
# Теперь подставим это значение.
students.loc[students.mother_edu.isnull() , 'mother_edu'] = 3.0
display(pd.DataFrame(students.mother_edu.value_counts()))
# Out:
#      mother_edu
# 4.0         131
# 2.0         102
# 3.0         100
# 1.0          59
# 0.0           3

# %%
print("Пустых значений:", students.mother_edu.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.father_edu.nunique())
print("Пустых значений:", students.father_edu.isnull().sum())
display(pd.DataFrame(students.father_edu.value_counts()))
students.father_edu.hist()
# Отцы подкачали, много кто закончил 5-9 классов.
# Out:
# Уникальных значений: 6
# Пустых значений: 24
#       father_edu
# 2.0          106
# 3.0           96
# 4.0           88
# 1.0           78
# 0.0            2
# 40.0           1

# %%
students.loc[students['father_edu'] == 40.0, 'father_edu'] = 4.0
# Также видим аномалию, похожую на человеческий фактор. Заменим на 4.0.

# %%
students.father_edu.median()
students.father_edu.mean()
# Заменим средним, которое чуть ближе к 3.0, чем к 2.0.
# Out:
# 2.5175202156334233

# %%
# Теперь подставим это значение.
students.loc[students.father_edu.isnull() , 'father_edu'] = 3.0
display(pd.DataFrame(students.father_edu.value_counts()))
# Out:
#      father_edu
# 3.0         120
# 2.0         106
# 4.0          89
# 1.0          78
# 0.0           2

# %%
print("Пустых значений:", students.father_edu.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.mother_job.nunique())
print("Пустых значений:", students.mother_job.isnull().sum())
display(pd.DataFrame(students.mother_job.value_counts()))
students.mother_job.hist()
# Больше значений other.
# Out:
# Уникальных значений: 5
# Пустых значений: 19
#           mother_job
# other            133
# services          98
# at_home           58
# teacher           55
# health            32

# %%
m_j = students[students.mother_job.isnull()]
m_j.mother_edu.value_counts()
# Смотрим какие значения mother_edu в пустых строках mother_job.
# Out:
# 4.0    7
# 3.0    6
# 2.0    4
# 1.0    2
# Name: mother_edu, dtype: int64

# %%
students.groupby(['mother_job','mother_edu']).mother_job.count()
# Сопоставим эти колонки и посмотрим как лучше распределить пустые значения.
# Out:
# mother_job  mother_edu
# at_home     0.0            2
#             1.0           25
#             2.0           21
#             3.0            8
#             4.0            2
# health      1.0            1
#             2.0            2
#             3.0            5
#             4.0           24
# other       0.0            1
#             1.0           26
#             2.0           45
#             3.0           39
#             4.0           22
# services    1.0            5
#             2.0           30
#             3.0           39
#             4.0           24
# teacher     3.0            3
#             4.0           52
# Name: mother_job, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['mother_edu'] == 1.0) & (students.mother_job.isnull()), 'mother_job'] = 'at_home'
students.loc[(students['mother_edu'] == 2.0) & (students.mother_job.isnull()), 'mother_job'] = 'other'
students.loc[(students['mother_edu'] == 3.0) & (students.mother_job.isnull()), 'mother_job'] = 'services'
students.loc[(students['mother_edu'] == 4.0) & (students.mother_job.isnull()), 'mother_job'] = 'health'
display(pd.DataFrame(students.mother_job.value_counts()))
# Out:
#           mother_job
# other            137
# services         104
# at_home           60
# teacher           55
# health            39

# %%
print("Пустых значений:", students.mother_job.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.father_job.nunique())
print("Пустых значений:", students.father_job.isnull().sum())
display(pd.DataFrame(students.father_job.value_counts()))
students.father_job.hist()
# Больше значений other.
# Out:
# Уникальных значений: 5
# Пустых значений: 36
#           father_job
# other            197
# services         102
# teacher           29
# at_home           16
# health            15

# %%
f_j = students[students.father_job.isnull()]
f_j.father_edu.value_counts()
# Смотрим какие значения father_edu в пустых строках father_job.
# Out:
# 2.0    14
# 3.0     9
# 1.0     7
# 4.0     6
# Name: father_edu, dtype: int64

# %%
students.groupby(['father_job','father_edu']).father_job.count()
# Сопоставим эти колонки и посмотрим как лучше распределить пустые значения.
# Out:
# father_job  father_edu
# at_home     1.0            3
#             2.0            6
#             3.0            5
#             4.0            2
# health      1.0            1
#             2.0            1
#             3.0            5
#             4.0            8
# other       0.0            2
#             1.0           48
#             2.0           58
#             3.0           58
#             4.0           31
# services    1.0           19
#             2.0           27
#             3.0           39
#             4.0           17
# teacher     3.0            4
#             4.0           25
# Name: father_job, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['father_edu'] == 1.0) & (students.father_job.isnull()), 'father_job'] = 'at_home'
students.loc[(students['father_edu'] == 2.0) & (students.father_job.isnull()), 'father_job'] = 'other'
students.loc[(students['father_edu'] == 3.0) & (students.father_job.isnull()), 'father_job'] = 'services'
students.loc[(students['father_edu'] == 4.0) & (students.father_job.isnull()), 'father_job'] = 'health'
display(pd.DataFrame(students.father_job.value_counts()))
# Out:
#           father_job
# other            211
# services         111
# teacher           29
# at_home           23
# health            21

# %%
print("Пустых значений:", students.father_job.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.reason.nunique())
print("Пустых значений:", students.reason.isnull().sum())
display(pd.DataFrame(students.reason.value_counts()))
students.reason.hist()
# Больше значений course.
# Out:
# Уникальных значений: 4
# Пустых значений: 17
#             reason
# course         137
# home           104
# reputation     103
# other           34

# %%
# Добавим 17 путых значений в other, т.к. остальные более менее равны.
students.loc[students.reason.isnull() , 'reason'] = 'other'
display(pd.DataFrame(students.reason.value_counts()))
# Out:
#             reason
# course         137
# home           104
# reputation     103
# other           51

# %%
print("Пустых значений:", students.reason.isnull().sum())
# Out:
# Пустых значений: 0

# %%
students.drop(['guardian'], inplace = True, axis = 1)
# Удаляем эту колонку, потому что 111 детей совершеннолетние. Опекунство не имеет смысла в этом датасете.

# %%
print("Уникальных значений:", students.traveltime.nunique())
print("Пустых значений:", students.traveltime.isnull().sum())
display(pd.DataFrame(students.traveltime.value_counts()))
students.traveltime.hist()
# Много кто добирается до школы менее, чем за 15 минут.
# Out:
# Уникальных значений: 4
# Пустых значений: 28
#      traveltime
# 1.0         242
# 2.0          96
# 3.0          22
# 4.0           7

# %%
t_t = students[students.traveltime.isnull()]
t_t.address.value_counts()
# Смотрим какие значения address в пустых строках traveltime.
# Out:
# U    21
# R     7
# Name: address, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['address'] == 'U') & (students.traveltime.isnull()), 'traveltime'] = 2.0
students.loc[(students['address'] == 'R') & (students.traveltime.isnull()), 'traveltime'] = 3.0
display(pd.DataFrame(students.traveltime.value_counts()))
# Out:
#      traveltime
# 1.0         242
# 2.0         117
# 3.0          29
# 4.0           7

# %%
print("Пустых значений:", students.traveltime.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.studytime.nunique())
print("Пустых значений:", students.studytime.isnull().sum())
display(pd.DataFrame(students.studytime.value_counts()))
students.studytime.hist()
# Много кто тратит время на учёбу помимо школы в неделю от 2-5 часов.
# Out:
# Уникальных значений: 4
# Пустых значений: 7
#      studytime
# 2.0        194
# 1.0        103
# 3.0         64
# 4.0         27

# %%
students.studytime.median()
# Заполним пустые значения медианой.
# Out:
# 2.0

# %%
# Теперь подставим это значение.
students.loc[students.studytime.isnull() , 'studytime'] = 2.0
display(pd.DataFrame(students.studytime.value_counts()))
# Out:
#      studytime
# 2.0        201
# 1.0        103
# 3.0         64
# 4.0         27

# %%
print("Пустых значений:", students.studytime.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.failures.nunique())
print("Пустых значений:", students.failures.isnull().sum())
display(pd.DataFrame(students.failures.value_counts()))
students.failures.hist()
# Большинство не имеет внеучебных неудач.
# Out:
# Уникальных значений: 4
# Пустых значений: 22
#      failures
# 0.0       293
# 1.0        49
# 2.0        16
# 3.0        15

# %%
# Предположим, что в пустых значениях ученики тоже молодцы.
students.loc[students.failures.isnull() , 'failures'] = 0.0
display(pd.DataFrame(students.failures.value_counts()))
# Out:
#      failures
# 0.0       315
# 1.0        49
# 2.0        16
# 3.0        15

# %%
print("Пустых значений:", students.failures.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.schoolsup.nunique())
print("Пустых значений:", students.schoolsup.isnull().sum())
display(pd.DataFrame(students.schoolsup.value_counts()))
students.schoolsup.hist()
# Большинство не имеют дополнительную образовательную поддержку.
# Out:
# Уникальных значений: 2
# Пустых значений: 9
#      schoolsup
# no         335
# yes         51

# %%
# Подставим пустые значения как большинство.
students.loc[students.schoolsup.isnull() , 'schoolsup'] = 'no'
display(pd.DataFrame(students.schoolsup.value_counts()))
# Out:
#      schoolsup
# no         344
# yes         51

# %%
print("Пустых значений:", students.schoolsup.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.famsup.nunique())
print("Пустых значений:", students.famsup.isnull().sum())
display(pd.DataFrame(students.famsup.value_counts()))
students.famsup.hist()
# Много кто имеет семейную образовательную поддержку.
# Out:
# Уникальных значений: 2
# Пустых значений: 39
#      famsup
# yes     219
# no      137

# %%
f_s = students[students.famsup.isnull()]
f_s.parent_status.value_counts()
# Смотрим какие значения parent_status в пустых строках famsup.
# Out:
# T    37
# A     2
# Name: parent_status, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['parent_status'] == 'T' ) & (students.famsup.isnull()), 'famsup'] = 'yes'
students.loc[(students['parent_status'] == 'A' ) & (students.famsup.isnull()), 'famsup'] = 'no'
display(pd.DataFrame(students.famsup.value_counts()))
# Out:
#      famsup
# yes     256
# no      139

# %%
print("Пустых значений:", students.famsup.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.paid.nunique())
print("Пустых значений:", students.paid.isnull().sum())
display(pd.DataFrame(students.paid.value_counts()))
students.paid.hist()
# Количество учеников, которые получают дополнительные платные занятия по математике, примерно одинаково.
# Out:
# Уникальных значений: 2
# Пустых значений: 40
#      paid
# no    200
# yes   155

# %%
p_d = students[students.paid.isnull()]
p_d.studytime.value_counts()
# Смотрим какие значения studytime в пустых строках paid.
# Out:
# 2.0    22
# 1.0    14
# 3.0     3
# 4.0     1
# Name: studytime, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['studytime'] > 2 ) & (students.paid.isnull()), 'paid'] = 'yes'
students.loc[(students['studytime'] <= 2 ) & (students.paid.isnull()), 'paid'] = 'no'
display(pd.DataFrame(students.paid.value_counts()))
# Out:
#      paid
# no    236
# yes   159

# %%
print("Пустых значений:", students.paid.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.activities.nunique())
print("Пустых значений:", students.activities.isnull().sum())
display(pd.DataFrame(students.activities.value_counts()))
students.activities.hist()
# Количество учеников, которые получают дополнительные внеучебные занятия, примерно одинаково.
# Out:
# Уникальных значений: 2
# Пустых значений: 14
#      activities
# yes         195
# no          186

# %%
a_s = students[students.activities.isnull()]
a_s.schoolsup.value_counts()
# Смотрим какие значения schoolsup в пустых строках activities.
# Out:
# no     7
# yes    7
# Name: schoolsup, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['schoolsup'] == 'no' ) & (students.activities.isnull()), 'activities'] = 'no'
students.loc[(students['schoolsup'] == 'yes' ) & (students.activities.isnull()), 'activities'] = 'yes'
display(pd.DataFrame(students.activities.value_counts()))
# Out:
#      activities
# yes         202
# no          193

# %%
print("Пустых значений:", students.activities.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.nursery.nunique())
print("Пустых значений:", students.nursery.isnull().sum())
display(pd.DataFrame(students.nursery.value_counts()))
students.nursery.hist()
# Большинство ходили в детский сад.
# Out:
# Уникальных значений: 2
# Пустых значений: 16
#      nursery
# yes      300
# no        79

# %%
# Подставим пустые значения как большинство.
students.loc[students.nursery.isnull() , 'nursery'] = 'yes'
display(pd.DataFrame(students.nursery.value_counts()))
# Out:
#      nursery
# yes      316
# no        79

# %%
print("Пустых значений:", students.nursery.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.higher.nunique())
print("Пустых значений:", students.higher.isnull().sum())
display(pd.DataFrame(students.higher.value_counts()))
students.higher.hist()
# Большинство хочет получить высшее образование.
# Out:
# Уникальных значений: 2
# Пустых значений: 20
#      higher
# yes     356
# no       19

# %%
# Подставим пустые значения как большинство.
students.loc[students.higher.isnull() , 'higher'] = 'yes'
display(pd.DataFrame(students.higher.value_counts()))
# Out:
#      higher
# yes     376
# no       19

# %%
print("Пустых значений:", students.higher.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.internet.nunique())
print("Пустых значений:", students.internet.isnull().sum())
display(pd.DataFrame(students.internet.value_counts()))
students.internet.hist()
# У большинства есть интернет дома.
# Out:
# Уникальных значений: 2
# Пустых значений: 34
#      internet
# yes       305
# no         56

# %%
# Пусть у пустых значений он тоже будет.
students.loc[students.internet.isnull() , 'internet'] = 'yes'
display(pd.DataFrame(students.internet.value_counts()))
# Out:
#      internet
# yes       339
# no         56

# %%
print("Пустых значений:", students.internet.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.romantic.nunique())
print("Пустых значений:", students.romantic.isnull().sum())
display(pd.DataFrame(students.romantic.value_counts()))
students.romantic.hist()
# Большинство не имеет любовных отношений.
# Out:
# Уникальных значений: 2
# Пустых значений: 31
#      romantic
# no        240
# yes       124

# %%
r_c = students[students.romantic.isnull()]
r_c.age.value_counts()
# Смотрим какие значения age в пустых строках romantic.
# Out:
# 15    11
# 16     7
# 18     6
# 17     6
# 19     1
# Name: age, dtype: int64

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['age'] <= 17 ) & (students.romantic.isnull()), 'romantic'] = 'no'
students.loc[(students['age'] >= 18 ) & (students.romantic.isnull()), 'romantic'] = 'yes'
display(pd.DataFrame(students.romantic.value_counts()))
# Out:
#      romantic
# no        264
# yes       131

# %%
print("Пустых значений:", students.romantic.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.famrel.nunique())
print("Пустых значений:", students.famrel.isnull().sum())
display(pd.DataFrame(students.famrel.value_counts()))
students.famrel.hist()
# У многих хорошие семейные отношения.
# Out:
# Уникальных значений: 5
# Пустых значений: 27
#      famrel
# 4.0     182
# 5.0      99
# 3.0      62
# 2.0      17
# 1.0       8

# %%
students.famrel.median()
# Заполним пустые значения медианой.
# Out:
# 4.0

# %%
# Теперь подставим это значение.
students.loc[students.famrel.isnull() , 'famrel'] = 4.0
display(pd.DataFrame(students.famrel.value_counts()))
# Out:
#      famrel
# 4.0     209
# 5.0      99
# 3.0      62
# 2.0      17
# 1.0       8

# %%
print("Пустых значений:", students.famrel.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.freetime.nunique())
print("Пустых значений:", students.freetime.isnull().sum())
display(pd.DataFrame(students.freetime.value_counts()))
students.freetime.hist()
# Много кто имеет достаточное количество свободного времени после школы.
# Out:
# Уникальных значений: 5
# Пустых значений: 11
#      freetime
# 3.0       153
# 4.0       112
# 2.0        63
# 5.0        38
# 1.0        18

# %%
students.freetime.median()
# Заполним пустые значения медианой.
# Out:
# 3.0

# %%
# Теперь подставим это значение.
students.loc[students.freetime.isnull() , 'freetime'] = 3.0
display(pd.DataFrame(students.freetime.value_counts()))
# Out:
#      freetime
# 3.0       164
# 4.0       112
# 2.0        63
# 5.0        38
# 1.0        18

# %%
print("Пустых значений:", students.freetime.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.goout.nunique())
print("Пустых значений:", students.goout.isnull().sum())
display(pd.DataFrame(students.goout.value_counts()))
students.goout.hist()
# В большинстве не много проводят время с друзьями.
# Out:
# Уникальных значений: 5
# Пустых значений: 8
#      goout
# 3.0    127
# 2.0    101
# 4.0     84
# 5.0     52
# 1.0     23

# %%
students.goout.median()
# Заполним пустые значения медианой.
# Out:
# 3.0

# %%
# Теперь подставим это значение.
students.loc[students.goout.isnull() , 'goout'] = 3.0
display(pd.DataFrame(students.goout.value_counts()))
# Out:
#      goout
# 3.0    135
# 2.0    101
# 4.0     84
# 5.0     52
# 1.0     23

# %%
print("Пустых значений:", students.goout.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.health.nunique())
print("Пустых значений:", students.health.isnull().sum())
display(pd.DataFrame(students.health.value_counts()))
students.health.hist()
# Много у кого отличное текущее состояние здоровья.
# Out:
# Уникальных значений: 5
# Пустых значений: 15
#      health
# 5.0     138
# 3.0      89
# 4.0      63
# 1.0      47
# 2.0      43

# %%
h_th = students[students.health.isnull()]
h_th.absences.value_counts()
# Смотрим какие значения absences в пустых строках health.
# Out:
# 0.0     5
# 2.0     3
# 6.0     2
# 4.0     2
# 11.0    1
# 12.0    1
# 8.0     1
# Name: absences, dtype: int64

# %%
students.absences.median()
# Для ориентира вычислим медиану пропущенных занятий учениками.
# Out:
# 4.0

# %%
# Распределим значения исходя из предположительного соответсвия данных.
students.loc[(students['absences'] == 0.0 ) & (students.health.isnull()), 'health'] = 5.0
students.loc[(students['absences'] <= 4.0 ) & (students.health.isnull()), 'health'] = 4.0
students.loc[(students['absences'] <= 12.0 ) & (students.health.isnull()), 'health'] = 3.0
display(pd.DataFrame(students.health.value_counts()))
# Out:
#      health
# 5.0     143
# 3.0      94
# 4.0      68
# 1.0      47
# 2.0      43

# %%
print("Пустых значений:", students.health.isnull().sum())
# Out:
# Пустых значений: 0

# %%
print("Уникальных значений:", students.absences.nunique())
print("Пустых значений:", students.absences.isnull().sum())
display(pd.DataFrame(students.absences.value_counts()))
students.absences.hist()
# Много кто не пропускал занятия.
# Out:
# Уникальных значений: 36
# Пустых значений: 12
#        absences
# 0.0         111
# 2.0          60
# 4.0          53
# 6.0          31
# 8.0          21
# 10.0         17
# 12.0         12
# 14.0         12
# 3.0           8
# 16.0          7
# 7.0           6
# 5.0           5
# 18.0          5
# 20.0          4
# 22.0          3
# 9.0           3
# 1.0           3
# 15.0          2
# 13.0          2
# 11.0          2
# 25.0          1
# 54.0          1
# 385.0         1
# 26.0          1
# 56.0          1
# 24.0          1
# 212.0         1
# 21.0          1
# 75.0          1
# 30.0          1
# 19.0          1
# 38.0          1
# 40.0          1
# 23.0          1
# 17.0          1
# 28.0          1

# %%
# Разброс значений большой, посмотрим выбросы.

# %%
IQR = students.absences.quantile(0.75) - students.absences.quantile(0.25)
perc25 = students.absences.quantile(0.25)
perc75 = students.absences.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75), "IQR: {}, ".format(IQR), "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
 
students.absences.loc[students.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 10, range = (10, 30), label = 'IQR')
 
plt.legend();
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, 20.0].

# %%
students = students.loc[students.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)] 
# Этот способ позволит нам отобрать экстремально низкие и экстремально высокие оценки.

# %%
print("Уникальных значений:", students.absences.nunique())
print("Пустых значений:", students.absences.isnull().sum())
display(pd.DataFrame(students.absences.value_counts()))
# Out:
# Уникальных значений: 21
# Пустых значений: 0
#       absences
# 0.0        111
# 2.0         60
# 4.0         53
# 6.0         31
# 8.0         21
# 10.0        17
# 12.0        12
# 14.0        12
# 3.0          8
# 16.0         7
# 7.0          6
# 18.0         5
# 5.0          5
# 20.0         4
# 1.0          3
# 9.0          3
# 11.0         2
# 13.0         2
# 15.0         2
# 19.0         1
# 17.0         1

# %%
print("Уникальных значений:", students.score.nunique())
print("Пустых значений:", students.score.isnull().sum())
display(pd.DataFrame(students.score.value_counts()))
students.score.hist()
# Баллы по госэкзамену по математике в основном средние.
# Out:
# Уникальных значений: 17
# Пустых значений: 5
#        score
# 50.0      53
# 55.0      42
# 0.0       36
# 75.0      31
# 65.0      30
# 60.0      29
# 70.0      27
# 40.0      26
# 45.0      23
# 80.0      16
# 30.0      14
# 35.0       9
# 90.0       9
# 25.0       7
# 95.0       5
# 85.0       3
# 100.0      1

# %%
# Много значений 0.0. Посмотрим является ли это выбросом.

# %%
IQR = students.score.quantile(0.75) - students.score.quantile(0.25)
perc25 = students.score.quantile(0.25)
perc75 = students.score.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75), "IQR: {}, ".format(IQR), "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
 
students.score.loc[students.score.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 10, range = (10, 30), label = 'IQR')
 
plt.legend();
# Out:
# 25-й перцентиль: 40.0, 75-й перцентиль: 70.0, IQR: 30.0,  Границы выбросов: [-5.0, 115.0].

# %%
# Нет не является.

# %%
students.score.median()
# Заполним пустые значения медианой.
# Out:
# 55.0

# %%
# Теперь подставим это значение.
students.loc[students.score.isnull(), 'score'] = 55.0
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print("Пустых значений:", students.score.isnull().sum())
# Out:
# Пустых значений: 0

# %%
students.isnull().sum() # Пустые значения отсутствуют.
# Out:
# school           0
# sex              0
# age              0
# address          0
# famsize          0
# parent_status    0
# mother_edu       0
# father_edu       0
# mother_job       0
# father_job       0
# reason           0
# traveltime       0
# studytime        0
# failures         0
# schoolsup        0
# famsup           0
# paid             0
# activities       0
# nursery          0
# higher           0
# internet         0
# romantic         0
# famrel           0
# freetime         0
# goout            0
# health           0
# absences         0
# score            0
# dtype: int64

# %%
# Перейдём к корреляционному и номинативному анализу.

# %%
sns.pairplot(students, kind = 'reg')

# %%
students.corr()
# Out:
#                  age  mother_edu  father_edu  traveltime  studytime  failures  \
# age         1.000000   -0.181989   -0.182185    0.071708   0.003046  0.199735
# mother_edu -0.181989    1.000000    0.609008   -0.188027   0.084044 -0.247298
# father_edu -0.182185    0.609008    1.000000   -0.149096   0.011207 -0.273585
# traveltime  0.071708   -0.188027   -0.149096    1.000000  -0.094217  0.098156
# studytime   0.003046    0.084044    0.011207   -0.094217   1.000000 -0.164218
# failures    0.199735   -0.247298   -0.273585    0.098156  -0.164218  1.000000
# famrel      0.061021   -0.022334   -0.029939   -0.014523   0.028387  0.002388
# freetime    0.054126    0.029773   -0.010554   -0.032112  -0.134463  0.092134
# goout       0.134305    0.048449    0.029274    0.012918  -0.034124  0.077904
# health     -0.064820   -0.059557    0.024533    0.043634  -0.083181  0.085546
# absences    0.151493    0.065338   -0.016614   -0.053562  -0.077897  0.086239
# ...

# %%
sns.heatmap(students.corr()) # Тепловая карта.

# %%
def get_stat_dif(column):
    cols = students.loc[:, column].value_counts().index[:]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(students.loc[students.loc[:, column] == comb[0], 'score'], 
                        students.loc[students.loc[:, column] == comb[1], 'score']).pvalue \
            <= 0.05/len(combinations_all): # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break

# %%
for col in ['school', 'sex', 'age', 'address', 'famsize', 'parent_status', 'mother_edu', 'father_edu', 'mother_job',
            'father_job', 'reason', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
            'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'health', 'absences']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки sex
# Найдены статистически значимые различия для колонки address
# Найдены статистически значимые различия для колонки mother_edu
# Найдены статистически значимые различия для колонки mother_job
# Найдены статистически значимые различия для колонки failures
# Найдены статистически значимые различия для колонки paid
# Найдены статистически значимые различия для колонки higher
# Найдены статистически значимые различия для колонки romantic
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3583: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize = (17, 5))
    sns.boxplot(x=column, y='score', 
                data=students.loc[students.loc[:, column].isin(students.loc[:, column].value_counts().index[:])],
               ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()

# %%
for col in ['sex', 'address', 'mother_job', 'paid',  'higher', 'romantic']:
    get_boxplot(col)

# %%
# Оставим эти важные переменные в датасете для дальнейшего построения модели.
student_performance = students.loc[:, ['sex', 'address', 'mother_edu', 'mother_job', 'failures', 'paid', 'higher', 'romantic']]
student_performance.head()
# Out:
#   sex address  mother_edu mother_job  failures paid higher romantic
# 0   F       U         4.0    at_home       0.0   no    yes       no
# 1   F       U         1.0    at_home       0.0   no    yes       no
# 2   F       U         1.0    at_home       3.0   no    yes       no
# 3   F       U         4.0     health       0.0  yes    yes      yes
# 4   F       U         3.0      other       0.0  yes    yes       no

# %%
#ВЫВОДЫ: 
#    В ДАННЫХ ПОЧТИ ВО ВСЕХ КОЛОНКАХ БЫЛИ ПРОПУЩЕНЫ ЗНАЧЕНИЯ, НО В НЕБОЛЬШИХ КОЛИЧЕСТВАХ!
#    ПУСТЫЕ ЗНАЧЕНИЯ ЗАПОЛНЕНЫ! ВСЁ ПРИВЕДЕНО В ПОРЯДОК.
#    ПОДПРАВЛЕНЫ НАЗВАНИЯ КОЛОНОК. В ЦЕЛОМ ДАННЫЕ ХОРОШИЕ.
#1.SEX - ДЕВОЧКИ УЧАТСЯ ЛУЧШЕ МАЛЬЧИКОВ.
#2.ADDRESS - УЧЕНИКИ, ПРОЖИВАЮЩИЕ В ГОРОДЕ УЧАТСЯ ЛУЧШЕ.
#3.MOTHER EDUCATION - ЧЕМ ВЫШЕ ОБРАЗОВАНИЕ МАМЫ, ТЕМ ЛУЧШЕ УЧЕНИКИ УЧАТСЯ. ВИДИМО МАМЫ ЗАНИМАЮТСЯ С ДЕТЬМИ БОЛЬШЕ ОТЦОВ.
#4.MOTHER JOB - ЕСЛИ МАМА РАБОТАЕТ УЧИТЕЛЕМ ИЛИ ВРАЧОМ, ТО ШАНСЫ СДАТЬ ЭКЗАМЕН У ДЕТЕЙ ВЫШЕ.
#5.FAILURES - ЧЕМ БОЛЬШЕ ВНЕУЧЕБНЫХ НЕУДАЧ, ЧЕМ МЕНЬШЕ ШАНСОВ СДАТЬ ЭКЗАМЕН.
#6.PAID - ДОПОЛНИТЕЛЬНЫЕ ПЛАТНЫЕ ЗАНЯТИЯ ПО МАТЕМАТИКЕ УЛУЧШАЮТ УЧЁБУ.
#7.HIGHER - СТРЕМЛЕНИЕ ПОЛУЧИТЬ ВЫСШЕЕ ОБРАЗОВАНИЕ ПОЛОЖИТЕЛЬНО СКАЗЫВАЕТСЯ НА СДАЧЕ ЭКЗАМЕНА.
#8.ROMANTIC - УЧЕНИКИ В РОМАНТИЧЕСКИХ ОТНОШЕНИЯХ УЧАТСЯ ХУЖЕ, ОТВЛЕКАЮТСЯ.
